# %%
def jubilacion_total(sueldo_clp,tasa,tiempo_años,capital_actual):
    
    for i in range(0,(tiempo_años*12)+1):
        
        if i==0:
            aporte = ((sueldo_clp/0.83)*(1+0.01/12))*0.1  + capital_actual
        else:   
            aporte = ((sueldo_clp/0.83)*(1+0.01/12))*0.1 + monto_ganado
        monto_ganado = aporte * (1+tasa/1200)
        print(f'{round(monto_ganado):,}')
        
    return f'{round(monto_ganado):,}'

print(jubilacion_total(1100000,6.17,8,88000000))
# Out:
# 88,585,789
# 89,174,590
# 89,766,419
# 90,361,291
# 90,959,221
# 91,560,225
# 92,164,320
# 92,771,521
# 93,381,844
# 93,995,304
# 94,611,919
# 95,231,705
# 95,854,677
# 96,480,853
# 97,110,248
# 97,742,879
# 98,378,762
# 99,017,916
# 99,660,355
# 100,306,098
# 100,955,161
# 101,607,562
# 102,263,317
# 102,922,443
# 103,584,958
# 104,250,880
# 104,920,226
# 105,593,014
# 106,269,260
# 106,948,984
# 107,632,202
# 108,318,934
# 109,009,196
# 109,703,008
# 110,400,387
# 111,101,351
# 111,805,920
# 112,514,111
# 113,225,944
# 113,941,436
# 114,660,608
# 115,383,477
# 116,110,063
# 116,840,385
# 117,574,462
# 118,312,313
# 119,053,958
# 119,799,416
# 120,548,707
# 121,301,851
# 122,058,868
# 122,819,776
# 123,584,597
# 124,353,350
# 125,126,056
# 125,902,735
# 126,683,408
# 127,468,094
# 128,256,815
# 129,049,592
# 129,846,444
# 130,647,394
# 131,452,462
# 132,261,669
# 133,075,037
# 133,892,587
# 134,714,341
# 135,540,319
# 136,370,545
# 137,205,040
# 138,043,825
# 138,886,923
# 139,734,355
# 140,586,146
# 141,442,315
# 142,302,887
# 143,167,884
# 144,037,328
# 144,911,242
# 145,789,650
# 146,672,574
# 147,560,038
# 148,452,065
# 149,348,679
# 150,249,903
# 151,155,760
# 152,066,275
# 152,981,472
# 153,901,374
# 154,826,006
# 155,755,393
# 156,689,557
# 157,628,525
# 158,572,321
# 159,520,970
# 160,474,496
# 161,432,925
# 161,432,925
